# %%
import pandas as pd
import seaborn as sns
df=pd.read_csv('data.csv')
df
# Out:
#      index Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0        0         P1   33     1.0            2.0          4.0           5.0
# 1        1        P10   17     1.0            3.0          1.0           5.0
# 2        2       P100   35     1.0            4.0          5.0           6.0
# 3        3      P1000   37     1.0            7.0          7.0           7.0
# 4        4       P101   46     1.0            6.0          8.0           7.0
# ..     ...        ...  ...     ...            ...          ...           ...
# 995    995       P995   44     1.0            6.0          7.0           7.0
# 996    996       P996   37     2.0            6.0          8.0           7.0
# 997    997       P997   25     2.0            NaN          5.0           6.0
# 998    998       P998   18     2.0            6.0          8.0           7.0
# 999    999       P999   47     1.0            6.0          5.0           6.0
#
# ...

# %%
df.head()
# Out:
#    index Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0      0         P1   33     1.0            2.0          4.0           5.0
# 1      1        P10   17     1.0            3.0          1.0           5.0
# 2      2       P100   35     1.0            4.0          5.0           6.0
# 3      3      P1000   37     1.0            7.0          7.0           7.0
# 4      4       P101   46     1.0            6.0          8.0           7.0
#
#    OccuPational Hazards  Genetic Risk  chronic Lung Disease  ...  Fatigue  \
# 0                   4.0           3.0                   2.0  ...      3.0
# 1                   3.0           4.0                   2.0  ...      1.0
# 2                   5.0           5.0                   4.0  ...      8.0
# 3                   7.0           6.0                   7.0  ...      4.0
# 4                   7.0           7.0                   6.0  ...      3.0
#
# ...

# %%
df.columns
# Out:
# Index(['index', 'Patient Id', 'Age', 'Gender', 'Air Pollution', 'Alcohol use',
#        'Dust Allergy', 'OccuPational Hazards', 'Genetic Risk',
#        'chronic Lung Disease', 'Balanced Diet', 'Obesity', 'Smoking',
#        'Passive Smoker', 'Chest Pain', 'Coughing of Blood', 'Fatigue',
#        'Weight Loss', 'Shortness of Breath', 'Wheezing',
#        'Swallowing Difficulty', 'Clubbing of Finger Nails', 'Frequent Cold',
#        'Dry Cough', 'Snoring', 'Level'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 26 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   index                     1000 non-null   int64
#  1   Patient Id                1000 non-null   object
#  2   Age                       1000 non-null   int64
#  3   Gender                    999 non-null    float64
#  4   Air Pollution             997 non-null    float64
#  5   Alcohol use               998 non-null    float64
#  6   Dust Allergy              998 non-null    float64
#  7   OccuPational Hazards      998 non-null    float64
#  8   Genetic Risk              999 non-null    float64
#  9   chronic Lung Disease      997 non-null    float64
#  10  Balanced Diet             995 non-null    float64
#  11  Obesity                   1000 non-null   int64
#  12  Smoking                   997 non-null    float64
# ...

# %%
cor=df.corr()
# Out:
# C:\Users\NARESH KUMAR\AppData\Local\Temp\ipykernel_12764\3379160116.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   cor=df.corr()

# %%
cor
# Out:
#                              index       Age    Gender  Air Pollution  \
# index                     1.000000  0.002674 -0.027821       0.049020
# Age                       0.002674  1.000000 -0.201186       0.099249
# Gender                   -0.027821 -0.201186  1.000000      -0.248687
# Air Pollution             0.049020  0.099249 -0.248687       1.000000
# Alcohol use               0.042699  0.153442 -0.230426       0.746086
# Dust Allergy              0.039300  0.035419 -0.204821       0.637191
# OccuPational Hazards      0.032134  0.063605 -0.194022       0.607480
# Genetic Risk              0.029716  0.074091 -0.223716       0.704162
# chronic Lung Disease      0.028144  0.129739 -0.208983       0.626714
# Balanced Diet             0.034807  0.007105 -0.102457       0.524917
# Obesity                   0.050584  0.034337 -0.125453       0.600539
# Smoking                   0.019164  0.076407 -0.209456       0.479432
# ...

# %%
sns.heatmap(df.corr())
# Out:
# C:\Users\NARESH KUMAR\AppData\Local\Temp\ipykernel_12764\58359773.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr())
# <AxesSubplot: >

# %%
cor['chronic Lung Disease']
# Out:
# index                       0.028144
# Age                         0.129739
# Gender                     -0.208983
# Air Pollution               0.626714
# Alcohol use                 0.764113
# Dust Allergy                0.619826
# OccuPational Hazards        0.858647
# Genetic Risk                0.836535
# chronic Lung Disease        1.000000
# Balanced Diet               0.620980
# Obesity                     0.602087
# Smoking                     0.577663
# Passive Smoker              0.572960
# Chest Pain                  0.783933
# Coughing of Blood           0.602710
# Fatigue                     0.249201
# Weight Loss                 0.106424
# Shortness of Breath         0.183176
# Wheezing                    0.057230
# Swallowing Difficulty       0.007688
# Clubbing of Finger Nails    0.296277
# Frequent Cold               0.031040
# Dry Cough                   0.116062
# Snoring                     0.044391
# Name: chronic Lung Disease, dtype: float64

# %%
from matplotlib import pyplot as plt
x=df['chronic Lung Disease']
y=df['Alcohol use']
plt.xlabel('chronic Lung Disease')
plt.ylabel('Alcohol use')
plt.bar(x,y)
plt.show()

# %%
axs=sns.lineplot(x='Alcohol use',y='chronic Lung Disease',data=df)

# %%
cor['Dust Allergy']
# Out:
# index                       0.039300
# Age                         0.035419
# Gender                     -0.204821
# Air Pollution               0.637191
# Alcohol use                 0.818429
# Dust Allergy                1.000000
# OccuPational Hazards        0.835971
# Genetic Risk                0.787692
# chronic Lung Disease        0.619826
# Balanced Diet               0.645827
# Obesity                     0.701396
# Smoking                     0.357973
# Passive Smoker              0.559873
# Chest Pain                  0.639706
# Coughing of Blood           0.624507
# Fatigue                     0.334462
# Weight Loss                 0.323146
# Shortness of Breath         0.519686
# Wheezing                    0.307042
# Swallowing Difficulty       0.031389
# Clubbing of Finger Nails    0.345146
# Frequent Cold               0.218884
# Dry Cough                   0.299084
# Snoring                     0.052215
# Name: Dust Allergy, dtype: float64

# %%
from matplotlib import pyplot as plt
x=df['Dust Allergy']
y=df['Air Pollution']
plt.xlabel('Dust Allergy')
plt.ylabel('Air Pollution')
plt.bar(x,y)
plt.show()

# %%
axs=sns.lineplot(x='Dust Allergy',y='Air Pollution',data=df)
